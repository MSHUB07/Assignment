# %% [markdown]
# 1. Who developed Python Programming Language?
# Ans-1 Guido van Rossum developed the python programming language.
#
# 2. Which type of Programming does Python support?
# Ans-2 Python is an interpreted programming language, supporting object-oriented, structure and functional programming.
#
# 3. Is Python case sensitive when dealing with identifiers?
# Ans-3 Yes, python is a case sensitive when dealing with identifiers.
#
# 4. What is the correct extension of the Python file?
# Ans-4 .py is the correct extension of the python file.
#
# 5. Is Python code compiled or interpreted?
# Ans-5 Python is an interpreted language, which means the source code of a python program is converted by the python virtual machine.
#
# 6. Name a few blocks of code used to define in Python language?
# Ans-6 A block is a piece of python program text that is executed as a unit. The following are block: a module, a function body, and a class definition.
#
# 7. State a character used to give single-line comments in Python?
# Ans-7 Hash Character(#) is used to give single line comments in python.
#
# 8. Mention functions which can help us to find the version of python that we are currently working on?
# Ans-8 The function sys.version can help us to find the version of python that we are currently working on.
#
# 9. Python supports the creation of anonymous functions at runtime, using a construct called
# Ans-9 “Lambda”
#
# 10. What does pip stand for python?
# Ans-10 Preferred installer program.
#
# 11. Mention a few built-in functions in python?
# Ans-11 print(), type(), dir(), input(), max()
#
# 12. What is the maximum possible length of an identifier in Python?
# Ans-12 An identifier can have a maximum length of 79 characters in python.
#
# 13. What are the benefits of using Python?
# Ans-13      -Write less, do more.
#              -large developer community.
#              -extensive libraries.
#              -wide range of use cases.
#
# 14. How is memory managed in Python?
# Ans-14 Memory in python is managed by python private heap space.
#
# 15. How to install Python on Windows and set path variables?
# Ans-15 Steps to install python on windows:
#              1. Open the official python website in your web browser.
#              2. Choose the latest python 3 release.
#              3. Download python executive installer.
#              4. Run executive installer.
#              5. Verify python is installed on windows
#              6. Verify pip was installed.
#        -Steps to set path variables in python:
#              1. Right click on my computer and click on properties.
#              2. Click on advanced system settings.
#              3. Click on environment variable tab.
#              4. Click on new tab of user variables.
#              5. Write path in variable name.
#              6. Copy the path of python folder.
#              7. Paste path of python in variable value.
#
# 16. Is indentation required in python?
# Ans-16 The indentation in python is very important because python uses indentation to indicate a block of code.
